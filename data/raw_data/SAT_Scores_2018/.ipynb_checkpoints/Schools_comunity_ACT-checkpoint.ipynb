# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
#files with data for analysis
# school_data = "raw_data/SAT_Scores_2018/cleaner_data_SAT.csv"
# School_Location = "raw_data/SAT_Scores_2018/free_reduced_lunch1718.csv"

school_data = "cleaner_data_SAT.csv"
School_Location = "free_reduced_lunch1718.csv"

# %%
schools = pd.read_csv(school_data)
schools_type = pd.read_csv(School_Location)

# %%
schools.head(5)
# Out:
#    School Dist Code School Dist Name       Test Component  State Avg Score  \
# 0               601   Appling County  Combined Test Score             1052
# 1               602  Atkinson County  Combined Test Score             1052
# 2               603     Bacon County  Combined Test Score             1052
# 3               604     Baker County  Combined Test Score             1052
# 4               605   Baldwin County  Combined Test Score             1052
#
#    Dist Avg Score Test Score Bracket
# 0          1020.0            Average
# 1           994.0            Average
# 2           972.0      Below Average
# 3           900.0      Below Average
# 4           944.0      Below Average

# %%
schools_type = schools_type[['State Agency ID [District] 2017-18','Agency Name',
                             'Urban-centric Locale [District] 2017-18', 'Total Race/Ethnicity [District] 2017-18',
                            'Free and Reduced Lunch Students [Public School] 2017-18']]
schools_type
#All_school = pd.merge(schools, students, how="left", on=["school_name", "school_name"])
# Out:
#      State Agency ID [District] 2017-18             Agency Name  \
# 0                                   601          APPLING COUNTY
# 1                                   602         ATKINSON COUNTY
# 2                                   761  ATLANTA PUBLIC SCHOOLS
# 3                                   603            BACON COUNTY
# 4                                   604            BAKER COUNTY
# ..                                  ...                     ...
# 227                                 755        WHITFIELD COUNTY
# 228                                 756           WILCOX COUNTY
# 229                                 757           WILKES COUNTY
# 230                                 758        WILKINSON COUNTY
# 231                                 759            WORTH COUNTY
#
#     Urban-centric Locale [District] 2017-18  \
# 0                           33-Town: Remote
# 1                          43-Rural: Remote
# 2                            11-City: Large
# 3                          41-Rural: Fringe
# 4                         42-Rural: Distant
# ..                                      ...
# 227                        41-Rural: Fringe
# 228                        43-Rural: Remote
# 229                        32-Town: Distant
# 230                       42-Rural: Distant
# 231                        32-Town: Distant
#
#      Total Race/Ethnicity [District] 2017-18  \
# 0                                       3639
# 1                                       1699
# 2                                      52147
# 3                                       2140
# 4                                        286
# ..                                       ...
# 227                                    13073
# 228                                     1185
# 229                                     1560
# 230                                     1396
# 231                                     3271
#
#     Free and Reduced Lunch Students [Public School] 2017-18
# 0                                                 3289
# 1                                                 1525
# 2                                                39580
# 3                                                 1583
# 4                                                  284
# ..                                                 ...
# 227                                               9234
# 228                                               1115
# 229                                               1469
# 230                                               1304
# 231                                               3003
#
# [232 rows x 5 columns]

# %%
schools_type = schools_type.rename(columns={'State Agency ID [District] 2017-18':'School Dist Code',
                                            'Urban-centric Locale [District] 2017-18':'Urban-centric Local',
                                           'Total Race/Ethnicity [District] 2017-18':'Total_student_Dist',
                                           'Free and Reduced Lunch Students [Public School] 2017-18':'Free_Reduced_Lunch_Students'})
schools_type
#df.rename(columns={"A": "a", "B": "c"})
All_school_type = pd.merge(schools, schools_type, how="left", on='School Dist Code')
All_school_type.head(5)
# Out:
#    School Dist Code School Dist Name       Test Component  State Avg Score  \
# 0               601   Appling County  Combined Test Score             1052
# 1               602  Atkinson County  Combined Test Score             1052
# 2               603     Bacon County  Combined Test Score             1052
# 3               604     Baker County  Combined Test Score             1052
# 4               605   Baldwin County  Combined Test Score             1052
#
#    Dist Avg Score Test Score Bracket      Agency Name Urban-centric Local  \
# 0          1020.0            Average   APPLING COUNTY     33-Town: Remote
# 1           994.0            Average  ATKINSON COUNTY    43-Rural: Remote
# 2           972.0      Below Average     BACON COUNTY    41-Rural: Fringe
# 3           900.0      Below Average     BAKER COUNTY   42-Rural: Distant
# 4           944.0      Below Average   BALDWIN COUNTY    32-Town: Distant
#
#    Total_student_Dist Free_Reduced_Lunch_Students
# 0                3639                        3289
# 1                1699                        1525
# 2                2140                        1583
# 3                 286                         284
# 4                5219                        3856

# %%
All_school_type["Free_Reduced_Lunch_Students"] = pd.to_numeric(All_school_type["Free_Reduced_Lunch_Students"])
All_school_type['Reduced_Lunch_Students_%'] = ((All_school_type['Free_Reduced_Lunch_Students'] /
                                                All_school_type['Total_student_Dist'])*100)

All_school_type.head(5)
# Out:
#    School Dist Code School Dist Name       Test Component  State Avg Score  \
# 0               601   Appling County  Combined Test Score             1052
# 1               602  Atkinson County  Combined Test Score             1052
# 2               603     Bacon County  Combined Test Score             1052
# 3               604     Baker County  Combined Test Score             1052
# 4               605   Baldwin County  Combined Test Score             1052
#
#    Dist Avg Score Test Score Bracket      Agency Name Urban-centric Local  \
# 0          1020.0            Average   APPLING COUNTY     33-Town: Remote
# 1           994.0            Average  ATKINSON COUNTY    43-Rural: Remote
# 2           972.0      Below Average     BACON COUNTY    41-Rural: Fringe
# 3           900.0      Below Average     BAKER COUNTY   42-Rural: Distant
# 4           944.0      Below Average   BALDWIN COUNTY    32-Town: Distant
#
#    Total_student_Dist  Free_Reduced_Lunch_Students  Reduced_Lunch_Students_%
# 0                3639                         3289                 90.381973
# 1                1699                         1525                 89.758682
# 2                2140                         1583                 73.971963
# 3                 286                          284                 99.300699
# 4                5219                         3856                 73.883886

# %%
Urban_centric = set(All_school_type['Urban-centric Local'])
Urban_centric
# Out:
# {'11-City: Large',
#  '12-City: Mid-size',
#  '13-City: Small',
#  '21-Suburb: Large',
#  '23-Suburb: Small',
#  '31-Town: Fringe',
#  '32-Town: Distant',
#  '33-Town: Remote',
#  '41-Rural: Fringe',
#  '42-Rural: Distant',
#  '43-Rural: Remote'}

# %%
All_school_type.loc[(All_school_type['Urban-centric Local'].str.contains("City")),'Urban-centric Local']='City'
All_school_type.loc[(All_school_type['Urban-centric Local'].str.contains("Suburb")),'Urban-centric Local']='Suburb'
All_school_type.loc[(All_school_type['Urban-centric Local'].str.contains("Town")),'Urban-centric Local']='Town'
All_school_type.loc[(All_school_type['Urban-centric Local'].str.contains("Rural")),'Urban-centric Local']='Rural'
#df.loc[(df.Event == 'Dance'),'Event']='Hip-Hop'
#df[df["A"].str.contains("Hello|Britain")]
All_school_type
# Out:
#      School Dist Code    School Dist Name       Test Component  \
# 0                 601      Appling County  Combined Test Score
# 1                 602     Atkinson County  Combined Test Score
# 2                 603        Bacon County  Combined Test Score
# 3                 604        Baker County  Combined Test Score
# 4                 605      Baldwin County  Combined Test Score
# ..                ...                 ...                  ...
# 419               786  Social Circle City  Combined Test Score
# 420               789    Thomasville City  Combined Test Score
# 421               791          Trion City  Combined Test Score
# 422               792       Valdosta City  Combined Test Score
# 423               793        Vidalia City  Combined Test Score
#
#      State Avg Score  Dist Avg Score Test Score Bracket         Agency Name  \
# 0               1052          1020.0            Average      APPLING COUNTY
# 1               1052           994.0            Average     ATKINSON COUNTY
# 2               1052           972.0      Below Average        BACON COUNTY
# 3               1052           900.0      Below Average        BAKER COUNTY
# 4               1052           944.0      Below Average      BALDWIN COUNTY
# ..               ...             ...                ...                 ...
# 419             1052          1050.0            Average  SOCIAL CIRCLE CITY
# 420             1052          1095.0            Average    THOMASVILLE CITY
# 421             1052          1080.0            Average          TRION CITY
# 422             1052           982.0      Below Average       VALDOSTA CITY
# 423             1052          1047.0            Average        VIDALIA CITY
#
#     Urban-centric Local  Total_student_Dist  Free_Reduced_Lunch_Students  \
# 0                  Town                3639                         3289
# 1                 Rural                1699                         1525
# 2                 Rural                2140                         1583
# 3                 Rural                 286                          284
# 4                  Town                5219                         3856
# ..                  ...                 ...                          ...
# 419                Town                1784                          827
# 420                Town                2876                         1929
# 421                Town                1401                          630
# 422                City                8383                         8383
# 423                Town                2534                         2072
#
#      Reduced_Lunch_Students_%
# 0                   90.381973
# 1                   89.758682
# 2                   73.971963
# 3                   99.300699
# 4                   73.883886
# ..                        ...
# 419                 46.356502
# 420                 67.072323
# 421                 44.967880
# 422                100.000000
# 423                 81.767956
#
# [424 rows x 11 columns]

# %%
#school_type_group = All_school_type.groupby(['Test Score Bracket', 'Urban-centric Local'])['Dist Avg Score'].count()
#school_type_group = All_school_type.groupby(['Urban-centric Local']).count()#['Test Score Bracket'].count()
#school_type_group

town_df = All_school_type.loc[All_school_type["Urban-centric Local"] == "Town", :]
town_df
# Out:
#      School Dist Code    School Dist Name       Test Component  \
# 0                 601      Appling County  Combined Test Score
# 4                 605      Baldwin County  Combined Test Score
# 11                609     Ben Hill County  Combined Test Score
# 28                617        Burke County  Combined Test Score
# 31                620       Camden County  Combined Test Score
# 32                621      Candler County  Combined Test Score
# 112               641         Dade County  Combined Test Score
# 114               643      Decatur County  Combined Test Score
# 139               645        Dodge County  Combined Test Score
# 150               649        Early County  Combined Test Score
# 155               653      Emanuel County  Combined Test Score
# 156               653      Emanuel County  Combined Test Score
# 195               661       Gilmer County  Combined Test Score
# 201               665        Grady County  Combined Test Score
# 236               673         Hart County  Combined Test Score
# 258               680   Jeff Davis County  Combined Test Score
# 263               685        Lamar County  Combined Test Score
# 267               688          Lee County  Combined Test Score
# 274               694        Macon County  Combined Test Score
# 278               698     McIntosh County  Combined Test Score
# 286               704       Morgan County  Combined Test Score
# 316               716      Pulaski County  Combined Test Score
# 318               718      Quitman County  Combined Test Score
# 320               720     Randolph County  Combined Test Score
# 336               724      Screven County  Combined Test Score
# 347               734      Telfair County  Combined Test Score
# 349               736       Thomas County  Combined Test Score
# 350               736       Thomas County  Combined Test Score
# 351               737         Tift County  Combined Test Score
# 358               742       Turner County  Combined Test Score
# 367               748         Ware County  Combined Test Score
# 369               750   Washington County  Combined Test Score
# 370               751        Wayne County  Combined Test Score
# 379               757       Wilkes County  Combined Test Score
# 381               759        Worth County  Combined Test Score
# 399               763         Bremen City  Combined Test Score
# 401               765        Calhoun City  Combined Test Score
# 402               766     Carrollton City  Combined Test Score
# 405               771       Commerce City  Combined Test Score
# 409               774         Dublin City  Combined Test Score
# 411               779      Jefferson City  Combined Test Score
# 419               786  Social Circle City  Combined Test Score
# 420               789    Thomasville City  Combined Test Score
# 421               791          Trion City  Combined Test Score
# 423               793        Vidalia City  Combined Test Score
#
#      State Avg Score  Dist Avg Score Test Score Bracket         Agency Name  \
# 0               1052          1020.0            Average      APPLING COUNTY
# 4               1052           944.0      Below Average      BALDWIN COUNTY
# 11              1052           960.0      Below Average     BEN HILL COUNTY
# 28              1052           973.0      Below Average        BURKE COUNTY
# 31              1052          1087.0            Average       CAMDEN COUNTY
# 32              1052          1033.0            Average      CANDLER COUNTY
# 112             1052          1080.0            Average         DADE COUNTY
# 114             1052           973.0      Below Average      DECATUR COUNTY
# 139             1052          1044.0            Average        DODGE COUNTY
# 150             1052           940.0      Below Average        EARLY COUNTY
# 155             1052           946.0      Below Average      EMANUEL COUNTY
# 156             1052           946.0      Below Average      EMANUEL COUNTY
# 195             1052          1041.0            Average       GILMER COUNTY
# 201             1052           976.0      Below Average        GRADY COUNTY
# 236             1052           996.0            Average         HART COUNTY
# 258             1052          1010.0            Average   JEFF DAVIS COUNTY
# 263             1052           996.0            Average        LAMAR COUNTY
# 267             1052          1081.0            Average          LEE COUNTY
# 274             1052           920.0      Below Average        MACON COUNTY
# 278             1052          1004.0            Average     MCINTOSH COUNTY
# 286             1052          1045.0            Average       MORGAN COUNTY
# 316             1052          1071.0            Average      PULASKI COUNTY
# 318             1052           881.0      Below Average      QUITMAN COUNTY
# 320             1052           861.0      Below Average     RANDOLPH COUNTY
# 336             1052          1006.0            Average      SCREVEN COUNTY
# 347             1052           984.0      Below Average      TELFAIR COUNTY
# 349             1052          1004.0            Average       THOMAS COUNTY
# 350             1052          1004.0            Average       THOMAS COUNTY
# 351             1052           968.0      Below Average         TIFT COUNTY
# 358             1052          1012.0            Average       TURNER COUNTY
# 367             1052          1024.0            Average         WARE COUNTY
# 369             1052           963.0      Below Average   WASHINGTON COUNTY
# 370             1052          1021.0            Average        WAYNE COUNTY
# 379             1052           962.0      Below Average       WILKES COUNTY
# 381             1052           979.0      Below Average        WORTH COUNTY
# 399             1052          1114.0            Average         BREMEN CITY
# 401             1052          1046.0            Average        CALHOUN CITY
# 402             1052          1056.0            Average     CARROLLTON CITY
# 405             1052          1012.0            Average       COMMERCE CITY
# 409             1052           929.0      Below Average         DUBLIN CITY
# 411             1052          1123.0      Above Average      JEFFERSON CITY
# 419             1052          1050.0            Average  SOCIAL CIRCLE CITY
# 420             1052          1095.0            Average    THOMASVILLE CITY
# 421             1052          1080.0            Average          TRION CITY
# 423             1052          1047.0            Average        VIDALIA CITY
#
#     Urban-centric Local  Total_student_Dist  Free_Reduced_Lunch_Students  \
# 0                  Town                3639                         3289
# 4                  Town                5219                         3856
# 11                 Town                3175                         3127
# 28                 Town                4206                         4206
# 31                 Town                9252                         4602
# 32                 Town                2195                         1976
# 112                Town                2145                         1217
# 114                Town                5184                         4890
# 139                Town                3171                         2638
# 150                Town                2052                         1990
# 155                Town                4332                         3839
# 156                Town                4332                         3839
# 195                Town                4131                         2703
# 201                Town                4696                         4236
# 236                Town                3567                         2182
# 258                Town                3133                         2412
# 263                Town                2692                         1947
# 267                Town                6455                         2740
# 274                Town                1370                         1361
# 278                Town                1380                         1181
# 286                Town                3089                         1379
# 316                Town                1331                         1217
# 318                Town                 333                          333
# 320                Town                 915                          914
# 336                Town                2346                         1856
# 347                Town                1757                         1695
# 349                Town                5835                         4525
# 350                Town                5835                         4525
# 351                Town                7868                         7580
# 358                Town                1237                         1218
# 367                Town                6134                         5527
# 369                Town                3103                         2685
# 370                Town                5394                         4098
# 379                Town                1560                         1469
# 381                Town                3271                         3003
# 399                Town                2284                          251
# 401                Town                4042                         2232
# 402                Town                5119                         3052
# 405                Town                1640                          925
# 409                Town                2381                         2381
# 411                Town                3724                          977
# 419                Town                1784                          827
# 420                Town                2876                         1929
# 421                Town                1401                          630
# 423                Town                2534                         2072
#
#      Reduced_Lunch_Students_%
# 0                   90.381973
# 4                   73.883886
# 11                  98.488189
# 28                 100.000000
# 31                  49.740597
# 32                  90.022779
# 112                 56.736597
# 114                 94.328704
# 139                 83.191422
# 150                 96.978558
# 155                 88.619575
# 156                 88.619575
# 195                 65.432099
# 201                 90.204429
# 236                 61.171853
# 258                 76.986914
# 263                 72.325409
# 267                 42.447715
# 274                 99.343066
# 278                 85.579710
# 286                 44.642279
# 316                 91.435011
# 318                100.000000
# 320                 99.890710
# 336                 79.113384
# 347                 96.471258
# 349                 77.549272
# 350                 77.549272
# 351                 96.339603
# 358                 98.464026
# 367                 90.104336
# 369                 86.529165
# 370                 75.973304
# 379                 94.166667
# 381                 91.806787
# 399                 10.989492
# 401                 55.220188
# 402                 59.621020
# 405                 56.402439
# 409                100.000000
# 411                 26.235231
# 419                 46.356502
# 420                 67.072323
# 421                 44.967880
# 423                 81.767956

# %%
town_gp = town_df.groupby(["Test Score Bracket"])["School Dist Code"].count()
town_ls = town_gp.to_list()
town_ls
# Out:
# [1, 27, 17]

# %%
aa_df = All_school_type.loc[All_school_type["Test Score Bracket"] == "Above Average", :]
aa_df = aa_df.groupby(["Urban-centric Local"])["School Dist Code"].count()
aa_df
# Out:
# Urban-centric Local
# Rural      4
# Suburb    25
# Town       1
# Name: School Dist Code, dtype: int64

# %%
av_df = All_school_type.loc[All_school_type["Test Score Bracket"] == "Average", :]
av_df = av_df.groupby(["Urban-centric Local"])["School Dist Code"].count()
av_df
# Out:
# Urban-centric Local
# City       23
# Rural     104
# Suburb    113
# Town       27
# Name: School Dist Code, dtype: int64

# %%
ba_df = All_school_type.loc[All_school_type["Test Score Bracket"] == "Below Average", :]
ba_df = ba_df.groupby(["Urban-centric Local"])["School Dist Code"].count()
ba_df
# Out:
# Urban-centric Local
# City      53
# Rural     40
# Suburb    17
# Town      17
# Name: School Dist Code, dtype: int64

# %%
#school_type_group = pd.DataFrame(school_type_group)
#school_type_group

# %%
# lista1 = school_type_group.index.tolist()
# print(lista1)


#Type_AA = Index[:][2] #Type_AA = school_type_group['Above Average']
#print(Type_AA)
# Type_Aveg = school_type_group['Average']
# Type_BA = school_type_group['Below Average']
#Index = school_type_group.index.tolist()
#print(Index[0][1])
#print(Index)
# #y_label

# city = [0, 23, 53]
# rural = rural_ls
# sub = sub_ls
# town = town_ls

aa_val = aa_df
av_val = av_df
ba_val = ba_df

index = set(All_school_type['Urban-centric Local'])
#index
bar_df = pd.DataFrame({"Above Average": aa_val,
                       "Average": av_val,
                       "Below Average": ba_val},
                       index = index)
#bar_df
ind = np.arange(len(bar_df.index))
bar_df.plot(kind='bar')
plt.xticks(ind, index, rotation='vertical')
plt.xlabel('District Community Type', labelpad=20, fontsize='18')
plt.ylabel('Number of District', fontsize='14')
plt.legend(fontsize='14')
plt.savefig("../Image/Schools_Located_vs_Sat_scores.png")
plt.show()
# #Type_AA = [0.1, 17.5, 40, 48, 52, 69, 88]
# #>>> Type_Aveg = [2, 8, 70, 1.5, 25, 12, 28]
# #>>> index = ['snail', 'pig', 'elephant',
# #...          'rabbit', 'giraffe', 'coyote', 'horse']
# >>> df = pd.DataFrame({'speed': speed,
# ...                    'lifespan': lifespan}, index=index)
# >>> ax = df.plot.bar(rot=0)
#ax = bar_df.plot.bar(rot=0)

# %%
bar_df.T.plot(kind='bar')
plt.legend(bbox_to_anchor=(1,1), fontsize='14')
plt.savefig("../Image/T_chools_Located_vs_Sat_scores.png")
plt.show()

# %%
All_school_type.head(5)
# Out:
#    School Dist Code School Dist Name       Test Component  State Avg Score  \
# 0               601   Appling County  Combined Test Score             1052
# 1               602  Atkinson County  Combined Test Score             1052
# 2               603     Bacon County  Combined Test Score             1052
# 3               604     Baker County  Combined Test Score             1052
# 4               605   Baldwin County  Combined Test Score             1052
#
#    Dist Avg Score Test Score Bracket      Agency Name Urban-centric Local  \
# 0          1020.0            Average   APPLING COUNTY                Town
# 1           994.0            Average  ATKINSON COUNTY               Rural
# 2           972.0      Below Average     BACON COUNTY               Rural
# 3           900.0      Below Average     BAKER COUNTY               Rural
# 4           944.0      Below Average   BALDWIN COUNTY                Town
#
#    Total_student_Dist  Free_Reduced_Lunch_Students  Reduced_Lunch_Students_%
# 0                3639                         3289                 90.381973
# 1                1699                         1525                 89.758682
# 2                2140                         1583                 73.971963
# 3                 286                          284                 99.300699
# 4                5219                         3856                 73.883886

# %%
#date = Southern_city_data['Date'].max()
x_Student_Free=All_school_type['Reduced_Lunch_Students_%']
y_Score=All_school_type['Dist Avg Score']
ratio_Score = All_school_type['Agency Name'].index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_Student_Free, y_Score)
#print(f"the intercept :{round(intercept,2)}");
regress_values_Score = x_Student_Free * slope + intercept
line_Score = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_Score = round(rvalue,2)
plt.style.use('seaborn')
sur = plt.scatter(x_Student_Free, y_Score, s=100, c=ratio_Score, cmap="Blues_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.plot(x_Student_Free,regress_values_Score,"black");
plt.annotate(line_Score,(20,970),fontsize=14, color="black")
plt.title(f"student free Cities vs. Score SAT", fontsize = "12")
plt.xlabel(f"% Students by School in Free Lunch", size=14)
plt.ylabel(f"Combined Test Score", size=14)
#plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('Combined Test Score')
plt.savefig("../Image/scatter_chart_scores_SAT.png")
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_Score,3)}");
print(f"Lat linear regression model :{line_Score}");
print(f"===================================================")
print(f"There is a strong negative correlation between Student in program Free Luch and reduce price\
. the correlation value is {round(correlation_Score*100,2)}% in fact the greater the number of students\
in the free or reduced price lunch program, the combined SAT score decreases directly proportionally.")
# Out:
# the intercept :1166.191
# correlation:-0.72
# Lat linear regression model :y = -2.13x + 1166.19
# ===================================================
# There is a strong negative correlation between Student in program Free Luch and reduce price. the correlation value is -72.0% in fact the greater the number of studentsin the free or reduced price lunch program, the combined SAT score decreases directly proportionally.
